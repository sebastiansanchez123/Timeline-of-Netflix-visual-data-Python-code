# %%
# Data taken from the following link: https://finance.yahoo.com/quote/NFLX/history?period1=1022112000&period2=1598572800&interval=1d&filter=history&frequency=1d
import pandas as pd
import matplotlib.pyplot as plt

# %%
stockprice = pd.read_csv("netflix.csv")

# %%
stockprice
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 4594  2020-08-21  496.459991  498.130005  490.000000  492.309998  492.309998
# 4595  2020-08-24  495.440002  501.000000  483.160004  488.809998  488.809998
# 4596  2020-08-25  488.190002  492.470001  485.089996  490.579987  490.579987
# 4597  2020-08-26  492.500000  549.039978  492.079987  547.530029  547.530029
# 4598  2020-08-27  537.780029  541.000000  521.250000  526.270020  526.270020
#
#          Volume
# 0     104790000
# ...

# %%
stockprice.plot(x="Date", y="Close", figsize=(16,10))

# %%
stockprice.plot(x="Date", y="Close", figsize=(16,10))
plt.yscale("log")
